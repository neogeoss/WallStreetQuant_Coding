# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import yfinance as yf

# %%
univ = ['SPY','META']
px = yf.download(univ, start='2016-01-01')['Close']
px
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker            META         SPY
# Date
# 2016-01-04  101.330154  169.471558
# 2016-01-05  101.835739  169.758163
# 2016-01-06  102.073639  167.616837
# 2016-01-07   97.067596  163.595428
# 2016-01-08   96.482727  161.799698
# ...                ...         ...
# 2026-06-12  566.454956  739.843994
# 2026-06-15  593.479980  752.890381
# 2026-06-16  600.210022  748.401978
# 2026-06-17  567.580017  739.056030
# 2026-06-18  577.219971  746.739990
#
# [2630 rows x 2 columns]

# %%
## get returns. Mostly daily percent returns
ret = px / px.shift() - 1
ret
# Out:
# Ticker          META       SPY
# Date
# 2016-01-04       NaN       NaN
# 2016-01-05  0.004989  0.001691
# 2016-01-06  0.002336 -0.012614
# 2016-01-07 -0.049043 -0.023992
# 2016-01-08 -0.006025 -0.010977
# ...              ...       ...
# 2026-06-12 -0.002551  0.005408
# 2026-06-15  0.047709  0.017634
# 2026-06-16  0.011340 -0.005962
# 2026-06-17 -0.054364 -0.012488
# 2026-06-18  0.016984  0.010397
#
# [2630 rows x 2 columns]

# %%
## set X and Y. Have to add constant
X = ret[['SPY']]
X = sm.add_constant(X)

Y = ret['META']

# %%
print(X)
print(Y)
# Out:
#             const       SPY
# Date
# 2016-01-04    1.0       NaN
# 2016-01-05    1.0  0.001691
# 2016-01-06    1.0 -0.012614
# 2016-01-07    1.0 -0.023992
# 2016-01-08    1.0 -0.010977
# ...           ...       ...
# 2026-06-12    1.0  0.005408
# 2026-06-15    1.0  0.017634
# 2026-06-16    1.0 -0.005962
# 2026-06-17    1.0 -0.012488
# 2026-06-18    1.0  0.010397
#
# [2630 rows x 2 columns]
# Date
# 2016-01-04         NaN
# 2016-01-05    0.004989
# 2016-01-06    0.002336
# 2016-01-07   -0.049043
# 2016-01-08   -0.006025
#                 ...
# 2026-06-12   -0.002551
# 2026-06-15    0.047709
# 2026-06-16    0.011340
# 2026-06-17   -0.054364
# 2026-06-18    0.016984
# Name: META, Length: 2630, dtype: float64

# %%
### can't do this - missing data

results = sm.OLS(Y, X).fit()
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# Cell In[6], line 3
#       1 ### can't do this - missing data
#       2
# ----> 3 results = sm.OLS(Y, X).fit()
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\regression\linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\regression\linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\regression\linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\base\model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\base\model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\base\model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\base\data.py:694, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     691     exog = np.asarray(exog)
#     693 klass = handle_data_class_factory(endog, exog)
# --> 694 return klass(endog, exog=exog, missing=missing, hasconst=hasconst, **kwargs)
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\base\data.py:90, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      88 self.const_idx = None
#      89 self.k_constant = 0
# ---> 90 self._handle_constant(hasconst)
#      91 self._check_integrity()
#      92 self._cache = {}
#
# File ~\anaconda3\envs\ml\Lib\site-packages\statsmodels\base\data.py:139, in ModelData._handle_constant(self, hasconst)
#     137 exog_max = np.max(self.exog, axis=0)
#     138 if not np.isfinite(exog_max).all():
# --> 139     raise MissingDataError("exog contains inf or nans")
#     140 exog_min = np.min(self.exog, axis=0)
#     141 const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %%
X = X.dropna()

# %%
Y = Y.dropna()

# %%
results = sm.OLS(Y, X).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   META   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     1560.
# Date:                Sat, 20 Jun 2026   Prob (F-statistic):          2.80e-268
# Time:                        17:30:11   Log-Likelihood:                 6652.7
# No. Observations:                2629   AIC:                        -1.330e+04
# Df Residuals:                    2627   BIC:                        -1.329e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.000      0.350      0.726      -0.001       0.001
# SPY            1.3205      0.033     39.501      0.000       1.255       1.386
# ==============================================================================
# Omnibus:                      863.784   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           127627.696
# Skew:                          -0.402   Prob(JB):                         0.00
# Kurtosis:                      37.124   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results.params
# Out:
# const    0.000132
# SPY      1.320454
# dtype: float64

# %%
results.tvalues
# Out:
# const     0.350185
# SPY      39.501493
# dtype: float64

# %%
## MEta reconstruction
META = results.params['SPY']*X['SPY'] + results.params['const'] + results.resid

# %%
(META-Y).abs().sum()
# Out:
# np.float64(1.8344700758454735e-16)

# %%
beta_constr = results.params['SPY']*X['SPY']
prediction = results.params['SPY']*X['SPY'] + results.params['const']
alpha_contr = results.params['const'] + results.resid

# %%
alpha_contr.corr(X['SPY'])
# Out:
# np.float64(1.0036466612824145e-15)

# %%
### Alpha contribution worked out
alpha_contr.mean()
# Out:
# np.float64(0.00013183188989168517)

# %%
### Information ratio is worked out
alpha_contr.mean()/alpha_contr.std()*np.sqrt(252)
# Out:
# np.float64(0.10860781579730845)

# %%
### alpha t - stat worked out
results.tvalues['const']
# Out:
# np.float64(0.35018529936261444)
