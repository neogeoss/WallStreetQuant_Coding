# %%
import numpy as np
import pandas as pd

dt = "20110107"
dt = pd.to_datetime(dt)

# %%
dt
# Out:
# Timestamp('2011-01-07 00:00:00')

# %%
print(dt.year)
# Out:
# 2011

# %%
print(dt.month)
# Out:
# 1

# %%
print(dt.day)
# Out:
# 7

# %%
print(dt.hour)
# Out:
# 0

# %%
print(dt.minute)
# Out:
# 0

# %%
print(dt.second)
# Out:
# 0

# %%
dt.weekday()
# Out:
# 4

# %%
pd.to_datetime('20110107 12:10:30')
# Out:
# Timestamp('2011-01-07 12:10:30')

# %%
dt.strftime('%Y%m%d')
# Out:
# '20110107'

# %%
dt + pd.tseries.offsets.Day()
# Out:
# Timestamp('2011-01-08 00:00:00')

# %%
dt + pd.tseries.offsets.Day(2)
# Out:
# Timestamp('2011-01-09 00:00:00')

# %%
dt + pd.tseries.offsets.BDay()
# Out:
# Timestamp('2011-01-10 00:00:00')

# %%
print(pd.tseries.offsets.MonthEnd().rollforward(dt))
# Out:
# 2011-01-31 00:00:00

# %%
print(pd.tseries.offsets.MonthEnd().rollback(dt))
# Out:
# 2010-12-31 00:00:00

# %%
dt1 = pd.to_datetime("20110101")

# %%
dt2 = pd.to_datetime("20120630")

# %%
diff = dt2-dt1
diff
# Out:
# Timedelta('546 days 00:00:00')

# %%
diff.days
# Out:
# 546

# %%
date = ['20110102', '20110103', '20110105']

dt_index = pd.DatetimeIndex(date)
dt_index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-03', '2011-01-05'], dtype='datetime64[ns]', freq=None)

# %%
dt_index[0]
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
days = pd.date_range(dt1,dt2, freq="D")
days
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05', '2011-01-06', '2011-01-07', '2011-01-08',
#                '2011-01-09', '2011-01-10',
#                ...
#                '2012-06-21', '2012-06-22', '2012-06-23', '2012-06-24',
#                '2012-06-25', '2012-06-26', '2012-06-27', '2012-06-28',
#                '2012-06-29', '2012-06-30'],
#               dtype='datetime64[ns]', length=547, freq='D')

# %%
months = pd.date_range('20110101','20121231',freq="M")
months
# Out:
# C:\Users\super\AppData\Local\Temp\ipykernel_19284\996863640.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = pd.date_range('20110101','20121231',freq="M")
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31',
#                '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31',
#                '2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31',
#                '2012-09-30', '2012-10-31', '2012-11-30', '2012-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
univ = ['SPY','TLT','VXX','QQQ']
days = pd.date_range('20190101','20210630',freq='min')
df = pd.DataFrame(np.random.randn(len(days),len(univ)),index=days, columns=univ)
df
# Out:
#                           SPY       TLT       VXX       QQQ
# 2019-01-01 00:00:00  0.109766 -0.294461  1.212189  0.665915
# 2019-01-01 00:01:00  0.881262  0.056069 -0.084243 -0.795874
# 2019-01-01 00:02:00  0.591742 -0.204931 -0.465073 -0.682335
# 2019-01-01 00:03:00  0.989109 -1.744451 -0.799017 -1.055559
# 2019-01-01 00:04:00 -0.009857  0.602873  0.424596 -1.444450
# ...                       ...       ...       ...       ...
# 2021-06-29 23:56:00 -1.201842  1.064816 -0.282200  0.892029
# 2021-06-29 23:57:00  0.665325 -1.236433  0.735449 -0.566870
# 2021-06-29 23:58:00  0.614627 -0.138910 -1.176616 -0.439527
# 2021-06-29 23:59:00  0.324939  1.141625  0.373422  0.636212
# 2021-06-30 00:00:00 -0.542089 -1.452936  0.598895 -1.332751
#
# [1311841 rows x 4 columns]

# %%
df.loc['2019-01-01 00:00:00']
# Out:
# SPY    0.109766
# TLT   -0.294461
# VXX    1.212189
# QQQ    0.665915
# Name: 2019-01-01 00:00:00, dtype: float64

# %%
df.resample("M").sum()
# Out:
# C:\Users\super\AppData\Local\Temp\ipykernel_19284\1336785658.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample("M").sum()
#                    SPY         TLT         VXX         QQQ
# 2019-01-31 -368.021883 -322.649122  103.359803    4.469193
# 2019-02-28  202.020358   34.014609  124.053549 -232.045713
# 2019-03-31 -408.076062  169.498471  106.003876 -121.036190
# 2019-04-30   63.539056  204.504417   95.132220  -55.277216
# 2019-05-31 -120.531746 -199.517248   81.361309  225.341102
# 2019-06-30 -224.051236   61.673768 -103.515401  222.591282
# 2019-07-31  102.921112   -2.593429 -277.114581 -130.680517
# 2019-08-31  -86.468331   28.200399  -98.169577 -183.668839
# 2019-09-30 -112.518195  171.661004   76.747458 -185.882385
# 2019-10-31  139.864691   68.760607  519.345490 -210.016487
# 2019-11-30 -231.810532 -147.905716 -108.906213  225.268636
# 2019-12-31  -55.267585 -163.397583  446.197504  188.838090
# 2020-01-31  282.472998  226.540424 -112.476172 -189.451848
# 2020-02-29 -260.552564 -114.352026 -180.514285  171.981564
# 2020-03-31  -81.913035 -175.123934  265.464399  132.293513
# 2020-04-30  553.344142  349.395731   44.847247 -267.811700
