# %%
aapl_ret = 0.01
market_ret = 0.02

# %%
print (aapl_ret)
print (market_ret)
# Out:
# 0.01
# 0.02

# %%
aapl_ret
# Out:
# 0.01

# %%
excess_ret = aapl_ret - market_ret

print(excess_ret)
# Out:
# -0.01
